# %%
import sys

#instalando pacotes
# !{sys.executable} -m pip install memoization

#importando pacotes
import pandas as pd
import seaborn as sns

#configurando pasta de serviços
sys.path.insert(0, '../services')

#importando serviços
import file_service as fs

# %%
gp2018 = fs.get_gastos_path(2018)

# %%
gastos2018 = pd.read_excel(gp2018, sheet_name='gastos-2018')
gastos2018
# Out:
#                  txNomeParlamentar           cpf  ideCadastro  \
# 0                           AVANTE           NaN          NaN
# 1                           AVANTE           NaN          NaN
# 2                           AVANTE           NaN          NaN
# 3                           AVANTE           NaN          NaN
# 4                           AVANTE           NaN          NaN
# 5                           AVANTE           NaN          NaN
# 6                           AVANTE           NaN          NaN
# 7                              DEM           NaN          NaN
# 8                              DEM           NaN          NaN
# 9                              DEM           NaN          NaN
# 10                             DEM           NaN          NaN
# 11                             DEM           NaN          NaN
# 12                             DEM           NaN          NaN
# 13                             DEM           NaN          NaN
# ...
